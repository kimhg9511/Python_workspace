# %%
import requests
from bs4 import BeautifulSoup as bs

url = 'https://news.v.daum.net/v/20200604174430776'
req = requests.get(url)
soup = bs(req.text, 'html.parser')

# %%
news_title = soup.select_one('h3.tit_view').text
news_content = "\n".join(list(map(lambda i:i.text, soup.select('div#harmonyContainer p'))))
news_comments = soup.select_one('div.cmt_info')
# print(soup)
# print(news_content)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head data-cloud-area="head">
# <style>
#              @import url('//t1.daumcdn.net/harmony_static/cloud/page/2603111efaebe3b9879c7b3c1417b82fff251095.css');
#             @import url('//t1.daumcdn.net/harmony_static/cloud/2020/06/01/components.cb4b7ebb5536aad570aa.css')
#         </style>
# <meta content="noindex" name="robots"/>
# <meta content="jAC8Wh9HOG" property="mccp:docId"/>
# <meta content="다음 뉴스" data-cloud="pc_html_head_meta" property="og:site_name"/>
# <meta content="'이재용 수사 공정했나' 심의 앞둔 檢 영장청구 적절한가" data-cloud="pc_html_head_meta" property="og:title"/>
# <meta content="20200604174430" data-cloud="pc_html_head_meta" property="og:regDate"/>
# <meta content="(서울=뉴스1) 윤수희 기자,박승희 기자,류석우 기자 = 이재용 삼성전자 부회장이 '삼성 합병 의혹'과 관련해 검찰수사심의위원회 소집 신청을 하자 검찰이 이틀 만에 구속영장을 청구했다. 검찰에서는 예정된 수순대로 진행했을 뿐이란 입장이지만 외부에서는 '수사심의위 신청 권리'를 무력화시킨 것이라는 비판이 나온다. 삼성물산-제일모직 합병과 삼성 경영권 부" data-cloud="pc_html_head_meta" property="og:description"/>
# ...
