# %%
import requests
from bs4 import BeautifulSoup as bs
import time
import fileIO as io

# %%
# news list crawling
def get_news_list():
    main_req = requests.get('https://news.daum.net/')
    main_soup = bs(main_req.text, 'html.parser')
    news_list = list(map(lambda i:i.attrs['href'].split('/')[-1], main_soup.select('a.link_txt')))
    cnt = 0
    for i in range(len(news_list)):
        if len(news_list[i - cnt]) != 17:
            del news_list[i - cnt]
            cnt += 1
    return news_list

# %%
code = get_news_list()
news_title_list = []
news_content_list = []
comments_list = []
headers = {'Authorization': 'Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..CoGzsU_jFEMH_Ll4wRfYSxy_TnHKNaG3dU8sRAt7L-k'}

for i in code:
#     print(i)
    url = 'https://news.v.daum.net/v/'
    req = requests.get(url + i)
    print('title,content req:',req.status_code)
    soup = bs(req.text, 'html.parser')
    # title
#     print(soup.select_one('h3.tit_view'))
    news_title = soup.select_one('h3.tit_view').text
    # content
    news_content = "\n".join(list(map(lambda i:i.text, soup.select('div#harmonyContainer p'))))
    news_title_list.append(news_title)
    news_content_list.append(news_content)
    # get comment count
    url = f'https://comment.daum.net/apis/v1/posts/@{i}'
    req = requests.get(url, headers=headers)
    print('count req:',req.status_code)
    commentCount = req.json()['commentCount']
    # comment
    cnt = 0
    tmp_comments_list = []
    while int(commentCount / 100) >= cnt:
        url = f'https://comment.daum.net/apis/v1/posts/@{i}/comments'
        params = f'parentId=0&offset=0&limit=100&sort=RECOMMEND&isInitial=true'
        params = list(map(lambda i: i.split('='),params.split('&')))
        params = {k: v for k, v in params}
        req = requests.get(url, headers=headers, params=params) 
        print('comment req:',req.status_code)
        comments = list(map(lambda i:i['content'].replace('\n',''), req.json()))
        tmp_comments_list.extend(comments)
        cnt = cnt + 1
        print('comment repeatation:',cnt)
#         print(tmp_comments_list)
        time.sleep(0.1)
    comments_list.append(tmp_comments_list)
    print(len(news_title_list), len(news_content_list), len(comments_list))
    time.sleep(0.1)
news_list = [(code[i], news_title_list[i], news_content_list[i], comments_list[i]) for i in range(len(code))]
news_json = [{'news_code': code[i], "news_title": news_title_list[i], "news_content": news_content_list[i], "news_comments": comments_list[i]} for i in range(len(code))]
io.list_to_csv('news.csv', news_list)
io.list_to_json('news.json', news_json)
# Out:
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 1 1 1
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 2 2 2
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 3 3 3
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 4 4 4
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 5 5 5
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 6 6 6
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 7 7 7
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 8 8 8
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 9 9 9
# title,content req: 200
# count req: 200
# comment req: 200
# comment repeatation: 1
# 10 10 10
# title,content req: 200
# count req: 200
# ...

# %%
# Out:
# 40
