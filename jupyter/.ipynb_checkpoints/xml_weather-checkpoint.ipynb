# %%
import urllib.request as req
import requests
from bs4 import BeautifulSoup as bs
import os.path
import time

# %%
url = 'http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108'
dt = time.strftime('%Y%m%d', time.localtime(time.time()))
xml_file = 'forecast_'+ dt + '.xml'

# %%
if not os.path.exists(xml_file):
    req.urlretrieve(url, xml_file)
xml = ''
with open(xml_file, 'r', encoding='utf-8') as file:
    xml = file.read()
    soup = bs(xml, 'html.parser')
    locations = soup.select('location')
    info = {}
    for location in locations:
        city = location.find('city').get_text()
        weather = location.find('wf').get_text()
        if not (weather in info):
            info[weather] = []
        info[weather].append(city)
        
for weather in info.keys():
    print('+', weather)
for name in info[weather]:
    print('|-', name)
# Out:
# + 맑음
# + 구름많음
# + 흐리고 비
# |- 광주
# |- 목포
# |- 여수
# |- 순천
# |- 광양
# |- 나주
# |- 전주
# |- 군산
# |- 정읍
# |- 남원
# |- 고창
# |- 무주
# |- 부산
# |- 울산
# |- 창원
# |- 진주
# |- 거창
# |- 통영
# |- 대구
# |- 안동
# |- 포항
# |- 경주
# |- 울진
# |- 울릉도
# |- 제주
# |- 서귀포

# %%
url = 'http://www.kweather.co.kr/forecast/forecast_living_jisu.html'
resp = requests.get(url)
soup = bs(resp.text)
xml_url = list(map(lambda i:i.attrs['href'].split('/')[-1].split('.xml')[0], soup.select('ul#jisu_navi_content a')))
xml_url
# Out:
# ['11B00000',
#  '11D10000',
#  '11D20000',
#  '11C10000',
#  '11C20000',
#  '11H10000',
#  '11H20000',
#  '11F10000',
#  '11F20000',
#  '11G00000']

# %%
for xml in xml_url:
    url = f'http://www.kweather.co.kr/data/JISU/{xml}.xml'
#     xml_file = 'kweather_'+ xml + '.xml'
#     # if not os.path.exists(xml_file):
#     req.urlretrieve(url, xml_file)
#     with open(xml_file, 'r', encoding='utf-8') as file:
#         r = file.read()
#         soup = bs(r,'html.parser')
#         print(soup.select_one('areaname'))
    resp = requests.get(url)
    resp.encoding = None
    soup = bs(resp.text)

    jisu_name = list(map(lambda i:i.text, soup.select('name')))
    jisu_num = list(map(lambda i:i.text, soup.select('jnum')))
    jisu_text = list(map(lambda i:i.text, soup.select('jtext')))
    print(jisu_name, jisu_num, jisu_text)
# Out:
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['80', '90', '90', '20', '20', '90', '60', '60', '60', '80', '80', '90', '40', '80', '70', '90', '90', '20', '20', '90', '60', '60', '60', '80', '90', '40', '60', '80', '70', '70', '90', '20', '20', '70', '60', '60', '60', '80', '90', '40', '70', '80'] ['더워서 걱정이네요', '아주 잘 말라요', '세차효과 길어요', '난방 불필요해요', '소화기 점검은 평소에', '컨디션이 좋습니다', '저항력을 높이세요', '대체로 좋은 편', '쾌적한 실내온도 유지하세요', '마음의 폭을 넓히세요', '장시간 야외활동은 위험해요', '모기 공격 조심', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '아주 잘 말라요', '세차하기 좋은날', '난방 불필요해요', '소화기 점검은 평소에', '컨디션이 좋습니다', '저항력을 높이세요', '대체로 좋은 편', '적당한 냉방이 필요해요', '말다툼은 금물', '장시간 야외활동은 위험해요', '모기가 힘이 없어요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '마르는데 지장 없어요', '광택도 내보세요', '난방은 필요없어요', '소화기 점검은 평소에', '수분공급 충분히', '저항력을 높이세요', '대체로 좋은 편', '활동시간에는 꼭 냉방 필요', '마음을 너그럽게 가지세요', '장시간 야외활동은 위험해요', '모기가 힘이 없어요', '부패 조심하세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['80', '90', '90', '20', '20', '90', '60', '60', '60', '75', '90', '80', '40', '80', '80', '90', '90', '20', '20', '90', '60', '60', '60', '75', '80', '30', '40', '80', '70', '70', '90', '20', '20', '70', '60', '60', '60', '80', '90', '40', '70', '80'] ['더워서 걱정이네요', '아주 잘 말라요', '세차하기 좋아요', '난방은 필요없어요', '소화기 점검은 평소에', '컨디션이 좋습니다', '실내공기 바꿔주세요', '대체로 좋은 편', '적당한 냉방이 필요해요', '차분한 마음 유지하세요', '장시간 야외활동은 위험해요', '모기약 필요해요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '더워서 걱정이네요', '이불 빨래도 잘 말라요', '세차효과 길어요', '난방 불필요해요', '소화기 점검은 평소에', '마음껏 즐기세요', '저항력을 높이세요', '공기 깨끗한 편이에요', '쾌적한 실내온도 유지하세요', '차분한 마음 유지하세요', '겉옷을 입어주세요', '모기약 필요없어요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '대체로 잘 말라요', '세차할 좋은 기회예요', '난방은 필요없어요', '소화기 점검은 평소에', '경기 즐길만 합니다', '실내공기 바꿔주세요', '공기 깨끗한 편이에요', '활동시간에는 꼭 냉방 필요', '오락영화 한편 감상하세요', '장시간 야외활동은 위험해요', '모기가 힘이 없어요', '부패 조심하세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['70', '90', '90', '20', '20', '90', '60', '60', '60', '80', '90', '50', '60', '80', '80', '90', '90', '20', '20', '70', '20', '60', '70', '85', '80', '40', '60', '80', '80', '70', '90', '20', '20', '70', '20', '60', '60', '80', '90', '40', '70', '80'] ['더위먹지 않도록 주의', '밀린 빨래 하세요', '세차하기 좋아요', '난방 불필요해요', '소화기 점검은 평소에', '운동으로 스트레스 푸세요', '저항력을 높이세요', '대체로 좋은 편', '활동시간에는 꼭 냉방 필요', '마음의 폭을 넓히세요', '바깥활동을 가급적 피하세요', '향수 사용 자제하세요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.', '더워서 걱정이네요', '아주 잘 말라요', '세차하기 좋아요', '난방은 필요없어요', '소화기 점검은 평소에', '더위로 쉽게 지칠 듯', '감기 걱정 없어요', '대체로 좋은 편', '한낮엔 충분히 냉방하세요', '농담도 삼가', '모자와 선글라스를 써주세요', '모기가 힘이 없어요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.', '나들이 괜찮아요', '마르는데 지장 없어요', '세차효과 길어요', '난방 불필요해요', '소화기 점검은 평소에', '아침저녁으로 즐기세요', '감기 걱정 없어요', '대체로 좋은 편', '활동시간에는 꼭 냉방 필요', '과격한 행동을 삼가세요', '바깥활동을 가급적 피하세요', '모기가 힘이 없어요', '부패 조심하세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['70', '90', '80', '20', '20', '90', '70', '60', '60', '80', '90', '80', '60', '80', '70', '90', '70', '20', '20', '90', '70', '60', '60', '80', '90', '40', '60', '80', '70', '60', '50', '20', '20', '70', '60', '60', '70', '85', '90', '40', '80', '80'] ['더위먹지 않도록 주의', '밀린 빨래 하세요', '세차하기 좋아요', '난방 불필요해요', '소화기 점검은 평소에', '운동으로 스트레스 푸세요', '큰 일교차에 주의하세요', '대체로 좋은 편', '적당한 냉방이 필요해요', '다툼에 유의하세요', '바깥활동을 가급적 피하세요', '모기약 뿌려 주세요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '밀린 빨래 하세요', '세차해도 괜찮아요', '난방 불필요해요', '소화기 점검은 평소에', '마음껏 즐기세요', '큰 일교차에 주의하세요', '대체로 좋은 편', '쾌적한 실내온도 유지하세요', '말다툼은 금물', '양산을 사용하세요', '모기가 힘이 없어요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '마르기 쉬운 옷으로', '짙은 먼지만 닦아 내세요', '보일러 가동 불필요해요', '소화기 점검은 평소에', '더위로 쉽게 지칠 듯', '실내공기 바꿔주세요', '대체로 좋은 편', '냉방병 조심하세요', '나보다 주위를 생각하세요', '바깥활동을 가급적 피하세요', '조금만 신경쓰세요', '요리해서 바로 드세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['80', '90', '80', '20', '20', '90', '60', '80', '50', '75', '90', '70', '40', '80', '70', '90', '70', '20', '20', '90', '70', '80', '60', '80', '90', '30', '40', '80', '80', '60', '50', '20', '20', '60', '60', '80', '60', '75', '90', '30', '60', '80'] ['더워서 걱정이네요', '밀린 빨래 하세요', '세차하기 좋은날', '보일러 가동 불필요해요', '소화기 점검은 평소에', '컨디션이 좋습니다', '저항력을 높이세요', '심호흡 한번 하세요', '아침저녁 냉방 필요없어요', '차분한 마음 유지하세요', '양산을 사용하세요', '아이들 모기 조심', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '빨래하기 아주 좋은 날씨', '세차해도 괜찮아요', '난방 불필요해요', '소화기 점검은 평소에', '컨디션이 좋습니다', '큰 일교차에 주의하세요', '맑은 공기가 필요해요', '활동시간에는 꼭 냉방 필요', '마음의 폭을 넓히세요', '자외선차단제를 수시로바르세요', '모기약 필요없어요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '더워서 걱정이네요', '마르기 쉬운 빨래감만', '짙은 먼지만 닦아 내세요', '보일러 가동 불필요해요', '소화기 점검은 평소에', '충분한 휴식과 함께', '습도와 환기에 신경쓰세요', '맑은 공기가 필요해요', '활동시간에는 꼭 냉방 필요', '다정한 말씨로', '양산을 사용하세요', '모기약 필요없어요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['80', '90', '50', '20', '20', '90', '60', '60', '50', '70', '90', '60', '40', '80', '80', '90', '40', '20', '20', '90', '20', '60', '50', '75', '90', '30', '40', '80', '70', '60', '30', '20', '20', '60', '60', '60', '60', '80', '90', '40', '80', '80'] ['나들이 즐길만 해요', '이불 빨래도 잘 말라요', '짙은 먼지만 닦아 내세요', '난방 불필요해요', '소화기 점검은 평소에', '운동으로 스트레스 푸세요', '습도와 환기에 신경쓰세요', '공기 깨끗한 편이에요', '낮 한때 냉방하세요', '자주 웃으세요', '양산을 사용하세요', '새벽에 모기 조심하세요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '나들이 괜찮아요', '이불 빨래도 잘 말라요', '조만간 비 예보가 있어요', '보일러 가동 불필요해요', '소화기 점검은 평소에', '마음껏 즐기세요', '감기 걱정 없어요', '대체로 좋은 편', '수면 중 냉방 필요없어요', '친절하게 행동하세요', '자외선차단제를 수시로바르세요', '모기 걱정 없어요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '마르기 쉬운 옷으로', '세차 미루세요', '난방 불필요해요', '소화기 점검은 평소에', '준비운동을 충분히', '실내공기 바꿔주세요', '공기 깨끗한 편이에요', '적당한 냉방이 필요해요', '마음의 폭을 넓히세요', '양산을 사용하세요', '조금만 신경쓰세요', '요리해서 바로 드세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['80', '90', '50', '20', '20', '90', '60', '60', '50', '70', '90', '60', '40', '80', '80', '90', '40', '20', '20', '90', '60', '60', '60', '75', '90', '30', '40', '80', '70', '60', '30', '20', '20', '60', '20', '60', '60', '75', '90', '30', '60', '80'] ['나들이 괜찮아요', '빨래하기 아주 좋은 날씨', '짙은 먼지만 닦아 내세요', '보일러 가동 불필요해요', '소화기 점검은 평소에', '마음껏 즐기세요', '저항력을 높이세요', '공기 깨끗한 편이에요', '아침저녁 냉방 필요없어요', '웃음이 보약', '바깥활동을 가급적 피하세요', '야외에선 특별한 주의를', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '더워서 걱정이네요', '빨래하기 아주 좋은 날씨', '미루는 것이 경제적', '보일러 가동 불필요해요', '소화기 점검은 평소에', '운동으로 스트레스 푸세요', '저항력을 높이세요', '대체로 좋은 편', '쾌적한 실내온도 유지하세요', '칭찬을 주고 받으세요', '바깥활동을 가급적 피하세요', '모기 걱정 없어요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '옷차림에 조금만 신경을', '마르기 쉬운 빨래감만', '세차 미루세요', '난방 불필요해요', '소화기 점검은 평소에', '충분한 휴식과 함께', '감기 걱정 없어요', '대체로 좋은 편', '활동시간에는 꼭 냉방 필요', '밝은 표정으로 생활하세요', '양산을 사용하세요', '모기 걱정 없어요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['70', '90', '50', '20', '20', '90', '60', '60', '60', '80', '90', '60', '60', '80', '70', '90', '40', '20', '20', '70', '60', '60', '70', '80', '90', '40', '60', '80', '70', '60', '30', '20', '20', '70', '60', '60', '70', '80', '70', '40', '80', '80'] ['더위먹지 않도록 주의', '밀린 빨래 하세요', '세차 효과 길진 않아요', '난방 불필요해요', '소화기 점검은 평소에', '컨디션이 좋습니다', '저항력을 높이세요', '대체로 좋은 편', '활동시간에는 꼭 냉방 필요', '심한 농담 삼가세요', '바깥활동을 가급적 피하세요', '저녁에 모기 조심하세요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '밀린 빨래 하세요', '급하지 않으면 다음에 하세요', '보일러 가동 불필요해요', '소화기 점검은 평소에', '한낮은 피하세요', '실내공기 바꿔주세요', '공기 깨끗한 편이에요', '한낮엔 충분히 냉방하세요', '느긋한 마음으로 생활하세요', '양산을 사용하세요', '조금만 신경쓰세요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.', '더위먹지 않도록 주의', '마르기 쉬운 옷으로', '다음에 하세요', '난방은 필요없어요', '소화기 점검은 평소에', '한낮은 피하세요', '저항력을 높이세요', '공기 깨끗한 편이에요', '에어컨 사용이 늘어요', '느긋한 마음으로 생활하세요', '야외활동 시 주의하세요', '모기가 힘이 없어요', '요리해서 바로 드세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['80', '90', '50', '20', '20', '90', '20', '70', '50', '70', '90', '80', '40', '80', '80', '90', '40', '20', '20', '90', '20', '70', '50', '70', '90', '30', '40', '80', '70', '60', '30', '20', '20', '60', '20', '60', '50', '75', '70', '30', '60', '80'] ['나들이 즐길만 해요', '아주 잘 말라요', '세차 효과 길진 않아요', '난방은 필요없어요', '소화기 점검은 평소에', '컨디션이 좋습니다', '감기 걱정 없어요', '외출 후엔 깨끗이', '아침저녁 냉방 필요없어요', '미소 지으세요', '바깥활동을 가급적 피하세요', '모기약 뿌려 주세요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '나들이 즐길만 해요', '밀린 빨래 하세요', '조만간 비 예보가 있어요', '보일러 가동 불필요해요', '소화기 점검은 평소에', '운동으로 스트레스 푸세요', '감기 걱정 없어요', '개인위생에 조금만 신경을', '한낮에는 냉방 필요해요', '자주 웃으세요', '바깥활동을 가급적 피하세요', '모기 걱정 없어요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '외출 지장 없어요', '마르기 쉬운 옷으로', '세차 미루세요', '난방은 필요없어요', '소화기 점검은 평소에', '준비운동을 충분히', '감기 걱정 없어요', '대체로 좋은 편', '한낮에는 냉방 필요해요', '친절하게 행동하세요', '야외활동 시 주의하세요', '모기 걱정 없어요', '냉장고에 보관하세요', '라운딩에 좋은 조건입니다.']
# ['나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프', '나들이', '빨래', '세차', '난방', '불조심', '운동', '감기', '공해', '냉방', '불쾌', '자외선', '모기', '부패', '골프'] ['80', '90', '40', '20', '20', '90', '20', '60', '40', '70', '90', '60', '40', '80', '80', '70', '30', '20', '20', '70', '20', '60', '50', '70', '90', '30', '50', '80', '50', '40', '20', '20', '20', '40', '20', '70', '50', '80', '90', '30', '70', '80'] ['나들이 즐길만 해요', '빨래하기 아주 좋은 날씨', '급하지 않으면 다음에 하세요', '난방은 필요없어요', '소화기 점검은 평소에', '컨디션이 좋습니다', '감기 걱정 없어요', '대체로 좋은 편', '필요하면 약간씩 하세요', '미소 지으세요', '자외선차단제를 수시로바르세요', '새벽에 모기 조심하세요', '냉장보관이 안전해요', '라운딩에 좋은 조건입니다.', '나들이 괜찮아요', '얇은 옷 잘 말라요', '다음에 하세요', '보일러 가동 불필요해요', '소화기 점검은 평소에', '아침저녁으로 즐기세요', '감기 걱정 없어요', '대체로 좋은 편', '한낮에는 냉방 필요해요', '미소 지으세요', '자외선차단제를 수시로바르세요', '모기 걱정 없어요', '낮에는 꼭 냉장보관을', '라운딩에 좋은 조건입니다.', '우산을 준비하세요', '실내건조가 안전해요', '세차 미루세요', '난방은 필요없어요', '소화기 점검은 평소에', '실내운동으로 만족하세요', '감기 걱정 없어요', '공기가 깨끗해져요', '한낮에는 냉방 필요해요', '말다툼은 금물', '장시간 야외활동은 위험해요', '모기약 필요없어요', '부패 조심하세요', '라운딩에 좋은 조건입니다.']
