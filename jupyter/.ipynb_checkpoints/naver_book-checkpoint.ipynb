# %% [markdown]
# # 네이버 책 검색기
# ## 요구사항
# ### 1.
# ### 2.

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import re
import pandas as pd
import csv
import json

# %%
# url - Requests - BeautifulSoup
url = 'https://book.naver.com/search/search.nhn'
params = 'sm=sta_hty.book&sug=&where=nexearch&query=bigdata'
params = list(map(lambda i: i.split('='),params.split('&')))
params = {k: v for k, v in params}
resp = req.get(url, params=params)
soup = bs(resp.text)

# %%
# find wanted data - title : description
book_all = soup.select_one('#searchBiblioList')
book_all_li = book_all.select('li')
book_all_title = list(map(lambda i : i['alt'], book_all.select('img[onerror]')))
book_all_content = soup.find_all(id=re.compile(r'^searchDescrition'))
remove = { ord('\n'): '', ord('\t'): '', ord('\r'): '', ord('\xa0'): ' : '}
book_all_content = list(map(lambda i: i.text.translate(remove), book_all_content)) 
book_info_all = {k: v for k in book_all_title for v in book_all_content}
# for k, v in book_info_all.items():
#     print(k, v)

# %%
# author / company / day / price

remove = { ord('\n'): '', ord('\xa0'): '', ord('\t'): '', ord('\r'): ''}
datablocks = soup.select('dd.txt_block')
datablocks = list(map(lambda i: i.text.translate(remove).split('|'), datablocks))
author = []
company = []
date = []
origin_price = []
saled_price = []
ebook_price = []
for datablock in datablocks:
    author.append(' '.join(datablock[0:-2]).strip())
    company.append(datablock[-2].strip())
    date.append(datablock[-1].strip())
datablocks = soup.select('.txt_desc:not(.txt_category)')
datablocks2 = soup.select_one('.txt_desc:not(.txt_category)')
def set_price(elem):
    origin_price = elem.select_one('strike')
    if origin_price != None:
        origin_price = origin_price.text.strip()
    saled_price = elem.select_one('em.price')
    if saled_price != None:
        saled_price = saled_price.text.strip()
    ebook_price = elem.select_one('img[alt="ebook구매"]')
    if ebook_price != None:
        ebook_price = elem.text.translate(remove).split('|')[-1].split(')')[-1].strip()
#     if elem.select_one('')
    return (origin_price, saled_price, ebook_price)
datablocks = list(map(lambda elem: set_price(elem),datablocks))
for data in datablocks:
    origin_price.append(data[0])
    saled_price.append(data[1])
    ebook_price.append(data[2])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-10-659f048fe6ae> in <module>
#      29 #     if elem.select_one('')
#      30     return (origin_price, saled_price, ebook_price)
# ---> 31 datablocks = list(map(lambda elem: set_price(elem),datablocks))
#      32 for data in datablocks:
#      33     origin_price.append(data[0])
#
# <ipython-input-10-659f048fe6ae> in <lambda>(elem)
#      29 #     if elem.select_one('')
#      30     return (origin_price, saled_price, ebook_price)
# ---> 31 datablocks = list(map(lambda elem: set_price(elem),datablocks))
#      32 for data in datablocks:
#      33     origin_price.append(data[0])
#
# <ipython-input-10-659f048fe6ae> in set_price(elem)
#      24         saled_price = saled_price.text.strip()
#      25     ebook_price = elem.select_one('img[alt="ebook구매"]')
# ---> 26     print(elem.select_one('.txt_desc:last_child'))
#      27     if ebook_price != None:
#      28         ebook_price = elem.text.translate(remove).split('|')[-1].split(')')[-1].strip()
#
# C:\ProgramData\Anaconda3\envs\collect\lib\site-packages\bs4\element.py in select_one(self, selector, namespaces, **kwargs)
#    1827         :rtype: bs4.element.Tag
#    1828         """
# -> 1829         value = self.select(selector, namespaces, 1, **kwargs)
#    1830         if value:
#    1831             return value[0]
#
# C:\ProgramData\Anaconda3\envs\collect\lib\site-packages\bs4\element.py in select(self, selector, namespaces, limit, **kwargs)
#    1862             )
#    1863
# -> 1864         results = soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    1865
#    1866         # We do this because it's more consistent and because
#
# C:\ProgramData\Anaconda3\envs\collect\lib\site-packages\soupsieve\__init__.py in select(select, tag, namespaces, limit, flags, **kwargs)
#      96     """Select the specified tags."""
#      97
# ---> 98     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#      99
#     100
#
# C:\ProgramData\Anaconda3\envs\collect\lib\site-packages\soupsieve\__init__.py in compile(pattern, namespaces, flags, **kwargs)
#      60         return pattern
#      61
# ---> 62     return cp._cached_css_compile(pattern, namespaces, custom, flags)
#      63
#      64
#
# C:\ProgramData\Anaconda3\envs\collect\lib\site-packages\soupsieve\css_parser.py in _cached_css_compile(pattern, namespaces, custom, flags)
#     206     return cm.SoupSieve(
#     207         pattern,
# --> 208         CSSParser(pattern, custom=custom_selectors, flags=flags).process_selectors(),
#     209         namespaces,
#     210         custom,
#
# C:\ProgramData\Anaconda3\envs\collect\lib\site-packages\soupsieve\css_parser.py in process_selectors(self, index, flags)
#    1041         """Process selectors."""
#    1042
# -> 1043         return self.parse_selectors(self.selector_iter(self.pattern), index, flags)
#    1044
#    1045
#
# C:\ProgramData\Anaconda3\envs\collect\lib\site-packages\soupsieve\css_parser.py in parse_selectors(self, iselector, index, flags)
#     900                     has_selector = self.parse_pseudo_class_custom(sel, m, has_selector)
#     901                 elif key == 'pseudo_class':
# --> 902                     has_selector, is_html = self.parse_pseudo_class(sel, m, has_selector, iselector, is_html)
#     903                 elif key == 'pseudo_element':
#     904                     raise NotImplementedError("Psuedo-element found at position {}".format(m.start(0)))
#
# C:\ProgramData\Anaconda3\envs\collect\lib\site-packages\soupsieve\css_parser.py in parse_pseudo_class(self, sel, m, has_selector, iselector, is_html)
#     638         else:
#     639             raise NotImplementedError(
# --> 640                 "'{}' pseudo-class is not implemented at this time".format(pseudo)
#     641             )
#     642
#
# NotImplementedError: ':last_child' pseudo-class is not implemented at this time

# %%
# pandas
books = {'author': author,
            'company': company,
            'date': date,
            'origin_price': origin_price,
            'saled_price': saled_price,
            'ebook_price': ebook_price}
books = pd.DataFrame(books)
books
# Out:
#                                                author  \
# 0                                     조치선, 정영진 외 5명 저
# 1                                      안지선 글   송진욱 그림
# 2                             김진호(대학교수), 최용주(대학부총장) 저
# 3                                   이범식 김은주 전소현 이상범 저
# 4                                        Petr Skoda 저
# 5                                       Vikas Khare 저
# 6                                               편집부 저
# 7                                               박형준 저
# 8                         Stephens-davidowitz, Seth 저
# 9                                      Dinesh Peter 저
# 10                                버나드 마 저   Ann Lee 역
# 11  Pedersen, John S. (EDT), Wilkinson, Adrian (ED...
# 12                                        조명화(여행작가) 저
# 13                  Sarangi, Saswat, Sharma, Pankaj 저
# 14                  Sarangi, Saswat, Sharma, Pankaj 저
# 15                                  Soraya Sedkaoui 저
# 16                                     Zhihua Zhang 저
# 17                                      이랑(가수), 황국영 저
# 18       Zgurovsky, Michael Z., Zaychenko, Yuriy P. 저
# 19                                 Yoshiki Yamagata 저
#
#                           company        date origin_price    saled_price  \
# 0                              엑셈  2019.09.25       25000원   22500원(-10%)
# 1                              봄볕  2018.05.16       13000원   11700원(-10%)
# 2                            북카라반  2018.07.25       16000원   14400원(-10%)
# 3                             구민사  2020.04.20       21000원    20370원(-3%)
# 4                        Elsevier  2020.04.22         None           None
# 5                        Elsevier  2020.04.21         None           None
# 6                       IRSGlobal  2019.02.26      390000원  351000원(-10%)
# 7                          리드리드출판  2018.07.27       15800원   14220원(-10%)
# 8                  DeyStreetBooks  2018.02.27       22220원   13880원(-38%)
# 9                        Elsevier  2020.03.09         None           None
# 10                            교학사  2016.03.20       14000원   12600원(-10%)
# 11                 EdwardElgarPub  2019.11.29      189540원   188320원(-1%)
# 12  테마여행신문TTNThemeTravelNewsKorea  2018.03.03         None           None
# 13                 RoutledgeIndia  2019.10.05       69650원   57120원(-18%)
# 14                 RoutledgeIndia  2019.10.03      196560원   177940원(-9%)
# 15                     Wiley-ISTE  2020.01.09         None           None
# 16                       Elsevier  2019.12.03         None           None
# 17                          소시민워크  2016.02.01         None           None
# 18      Springer-NatureNewYorkInc  2019.07.05      214180원  190630원(-11%)
# 19                       Elsevier  2019.11.03         None           None
#
#    ebook_price
# 0         None
# 1        8190원
# 2         None
# 3         None
# 4      121410원
# 5      151770원
# 6         None
# 7        9954원
# 8         None
# 9      121410원
# 10        None
# 11        None
# 12       8910원
# 13        None
# 14        None
# 15        None
# 16     151770원
# 17        None
# 18        None
# 19     151770원

# %%
# csv
with open('books.csv','w',encoding='utf-8') as books:
    writer = csv.writer(books)
    for i in range(len(author)):
        writer.writerow((author[i], company[i], date[i], origin_price[i], saled_price[i], ebook_price[i]))
with open('books.csv','r',encoding='utf-8') as books:
    reader = csv.reader(books)
    for row in reader:
        print(','.join(row))
# Out:
# 조치선, 정영진 외 5명 저,엑셈,2019.09.25,25000원,22500원(-10%),
#
# 안지선 글   송진욱 그림,봄볕,2018.05.16,13000원,11700원(-10%),8190원
#
# 김진호(대학교수), 최용주(대학부총장) 저,북카라반,2018.07.25,16000원,14400원(-10%),
#
# 이범식 김은주 전소현 이상범 저,구민사,2020.04.20,21000원,20370원(-3%),
#
# Petr Skoda 저,Elsevier,2020.04.22,,,121410원
#
# Vikas Khare 저,Elsevier,2020.04.21,,,151770원
#
# 편집부 저,IRSGlobal,2019.02.26,390000원,351000원(-10%),
#
# 박형준 저,리드리드출판,2018.07.27,15800원,14220원(-10%),9954원
#
# Stephens-davidowitz, Seth 저,DeyStreetBooks,2018.02.27,22220원,13880원(-38%),
#
# Dinesh Peter 저,Elsevier,2020.03.09,,,121410원
#
# 버나드 마 저   Ann Lee 역,교학사,2016.03.20,14000원,12600원(-10%),
#
# Pedersen, John S. (EDT), Wilkinson, Adrian (EDT) 저,EdwardElgarPub,2019.11.29,189540원,188320원(-1%),
#
# 조명화(여행작가) 저,테마여행신문TTNThemeTravelNewsKorea,2018.03.03,,,8910원
#
# Sarangi, Saswat, Sharma, Pankaj 저,RoutledgeIndia,2019.10.05,69650원,57120원(-18%),
#
# Sarangi, Saswat, Sharma, Pankaj 저,RoutledgeIndia,2019.10.03,196560원,177940원(-9%),
#
# Soraya Sedkaoui 저,Wiley-ISTE,2020.01.09,,,
#
# Zhihua Zhang 저,Elsevier,2019.12.03,,,151770원
#
# 이랑(가수), 황국영 저,소시민워크,2016.02.01,,,
#
# Zgurovsky, Michael Z., Zaychenko, Yuriy P. 저,Springer-NatureNewYorkInc,2019.07.05,214180원,190630원(-11%),
#
# Yoshiki Yamagata 저,Elsevier,2019.11.03,,,151770원

# %%
# json
json_books = []
with open('books.json','w',encoding='utf-8-sig') as books:
    for i in range(len(author)):
        json_book = {'author': author[i],
                'company': company[i],
                'date': date[i],
                'origin_price': origin_price[i],
                'saled_price': saled_price[i],
                'ebook_price': ebook_price[i]}
        json_books.append(json_book)
    books.write(json.dumps(json_books, ensure_ascii=False, indent=4))
data = []

with open('books.json','r',encoding='utf-8-sig') as books:
    data = json.loads(books.read())
print(data)
# Out:
# [{'author': '조치선, 정영진 외 5명 저', 'company': '엑셈', 'date': '2019.09.25', 'origin_price': '25000원', 'saled_price': '22500원(-10%)', 'ebook_price': None}, {'author': '안지선 글   송진욱 그림', 'company': '봄볕', 'date': '2018.05.16', 'origin_price': '13000원', 'saled_price': '11700원(-10%)', 'ebook_price': '8190원'}, {'author': '김진호(대학교수), 최용주(대학부총장) 저', 'company': '북카라반', 'date': '2018.07.25', 'origin_price': '16000원', 'saled_price': '14400원(-10%)', 'ebook_price': None}, {'author': '이범식 김은주 전소현 이상범 저', 'company': '구민사', 'date': '2020.04.20', 'origin_price': '21000원', 'saled_price': '20370원(-3%)', 'ebook_price': None}, {'author': 'Petr Skoda 저', 'company': 'Elsevier', 'date': '2020.04.22', 'origin_price': None, 'saled_price': None, 'ebook_price': '121410원'}, {'author': 'Vikas Khare 저', 'company': 'Elsevier', 'date': '2020.04.21', 'origin_price': None, 'saled_price': None, 'ebook_price': '151770원'}, {'author': '편집부 저', 'company': 'IRSGlobal', 'date': '2019.02.26', 'origin_price': '390000원', 'saled_price': '351000원(-10%)', 'ebook_price': None}, {'author': '박형준 저', 'company': '리드리드출판', 'date': '2018.07.27', 'origin_price': '15800원', 'saled_price': '14220원(-10%)', 'ebook_price': '9954원'}, {'author': 'Stephens-davidowitz, Seth 저', 'company': 'DeyStreetBooks', 'date': '2018.02.27', 'origin_price': '22220원', 'saled_price': '13880원(-38%)', 'ebook_price': None}, {'author': 'Dinesh Peter 저', 'company': 'Elsevier', 'date': '2020.03.09', 'origin_price': None, 'saled_price': None, 'ebook_price': '121410원'}, {'author': '버나드 마 저   Ann Lee 역', 'company': '교학사', 'date': '2016.03.20', 'origin_price': '14000원', 'saled_price': '12600원(-10%)', 'ebook_price': None}, {'author': 'Pedersen, John S. (EDT), Wilkinson, Adrian (EDT) 저', 'company': 'EdwardElgarPub', 'date': '2019.11.29', 'origin_price': '189540원', 'saled_price': '188320원(-1%)', 'ebook_price': None}, {'author': '조명화(여행작가) 저', 'company': '테마여행신문TTNThemeTravelNewsKorea', 'date': '2018.03.03', 'origin_price': None, 'saled_price': None, 'ebook_price': '8910원'}, {'author': 'Sarangi, Saswat, Sharma, Pankaj 저', 'company': 'RoutledgeIndia', 'date': '2019.10.05', 'origin_price': '69650원', 'saled_price': '57120원(-18%)', 'ebook_price': None}, {'author': 'Sarangi, Saswat, Sharma, Pankaj 저', 'company': 'RoutledgeIndia', 'date': '2019.10.03', 'origin_price': '196560원', 'saled_price': '177940원(-9%)', 'ebook_price': None}, {'author': 'Soraya Sedkaoui 저', 'company': 'Wiley-ISTE', 'date': '2020.01.09', 'origin_price': None, 'saled_price': None, 'ebook_price': None}, {'author': 'Zhihua Zhang 저', 'company': 'Elsevier', 'date': '2019.12.03', 'origin_price': None, 'saled_price': None, 'ebook_price': '151770원'}, {'author': '이랑(가수), 황국영 저', 'company': '소시민워크', 'date': '2016.02.01', 'origin_price': None, 'saled_price': None, 'ebook_price': None}, {'author': 'Zgurovsky, Michael Z., Zaychenko, Yuriy P. 저', 'company': 'Springer-NatureNewYorkInc', 'date': '2019.07.05', 'origin_price': '214180원', 'saled_price': '190630원(-11%)', 'ebook_price': None}, {'author': 'Yoshiki Yamagata 저', 'company': 'Elsevier', 'date': '2019.11.03', 'origin_price': None, 'saled_price': None, 'ebook_price': '151770원'}]

# %%
print(soup.select_one('.txt_desc:not(.txt_category):last-child'))
# Out:
# <dd class="txt_desc txt_category">
# <span class="theme">카테고리</span>
# <a class="N=a:bls.category,r:2,i:98000001_000000000000000000CF5471" href="http://book.naver.com/category/index.nhn?cate_code=320">어린이</a> &gt; <a class="N=a:bls.category,r:2,i:98000001_000000000000000000CF5471" href="http://book.naver.com/category/index.nhn?cate_code=320030&amp;tab=top100&amp;list_type=list&amp;sort_type=salecount">초등5~6학년</a> &gt; <a class="N=a:bls.category,r:2,i:98000001_000000000000000000CF5471" href="http://book.naver.com/category/index.nhn?cate_code=320030030&amp;tab=top100&amp;list_type=list&amp;sort_type=salecount">교양/취미</a></dd>
