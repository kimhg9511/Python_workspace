# %%
import requests
import folium
from bs4 import BeautifulSoup as bs

# %%
url = 'https://www.goobne.co.kr/store/search_store.jsp'
resp = requests.get(url)
soup = bs(resp.text)
soup.select('td.store_phone')
soup = bs(resp.text)
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!-- Header doc -->
# <title>굽네치킨</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="0929bebe183f961be860bccacc4d5c1c048ec5e8" name="naver-site-verification"/>
# <!-- 네이버 봇 정보 -->
# <meta content="오븐구이 전문 치킨&amp;피자 프랜차이즈, 굽네 갈비천왕, 굽네 볼케이노, 그릴드비프 갈비천왕 피자 등 메뉴소개, 창업정보, 온라인주문" name="description"/>
# <link href="https://www.goobne.co.kr/" rel="canonical"/>
# <meta content="https://www.goobne.co.kr/" property="og:url"/>
# <meta content="굽네치킨" property="og:site_name"/>
# <meta content="굽네치킨" property="og:title"/>
# <meta content="오븐구이 전문 치킨&amp;피자 프랜차이즈, 굽네 갈비천왕, 굽네 볼케이노, 그릴드비프 갈비천왕 피자 등 메뉴소개, 창업정보, 온라인주문" property="og:description"/>
# <meta content="website" property="og:type"/>
# <!-- <meta property="og:image"  content="http://" /> -->
# ...
