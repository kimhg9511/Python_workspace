# %%
import requests
from bs4 import BeautifulSoup as bs
import zipfile
from urllib import request as req
import bs4.element as elem
from konlpy.tag import Okt
from konlpy.tag import Hannanum
from konlpy.tag import Kkma
import collections
import re
# import pandas as pd

# %% [markdown]
# # 모든 회사의 정보

# %%
url = 'https://opendart.fss.or.kr/api/corpCode.xml?crtfc_key=f34638c11aaa3ed9ee3fbbabec9b0a9762a4a628'
downfile = 'corp_code.zip'
req.urlretrieve(url, downfile)
xml = ''
corp_list = []
with zipfile.ZipFile(downfile) as z:
    z.extractall()
    xml = z.filelist[0].filename
with open(xml,'r', encoding='utf-8') as f:
    soup = bs(f.read())
    corp_list = soup.select('list')

# %%
corp_name = input('찾고자 하는 종목 입력 : ')
corp_code = ''
for item in corp_list:
    if item.select_one('corp_name').text == corp_name:
        corp_code = item.select_one('corp_code').text
print(corp_name, corp_code)
# Out:
# 찾고자 하는 종목 입력 : 삼성바이오로직스
# 삼성바이오로직스 00877059

# %% [markdown]
# # 분기보고서 찾기

# %%
url = 'https://opendart.fss.or.kr/api/list.json'
params = {
    'crtfc_key': 'f34638c11aaa3ed9ee3fbbabec9b0a9762a4a628',
    'bgn_de': '20200101',
    'corp_code': corp_code,
    'pblntf_ty': 'A'
}
resp = requests.get(url, params=params)
report_list = resp.json()['list']
rcept_no = ''
for report in report_list:
    if report['report_nm'].split(' ')[0] == '분기보고서':
        rcept_no = report['rcept_no']

# %% [markdown]
# # 분기보고서 데이터 가져오기

# %%
url = 'https://opendart.fss.or.kr/api/document.xml'
url += '?crtfc_key=f34638c11aaa3ed9ee3fbbabec9b0a9762a4a628'
url += f'&rcept_no={rcept_no}'
downfile = 'quarter_rep.zip'
req.urlretrieve(url, downfile)

xml = ''
elem = elem
with zipfile.ZipFile(downfile) as z:
    z.extractall()
    xml = z.filelist[0].filename
with open(xml,'r') as f:
    soup = bs(f.read())
    elem = soup.select_one('title[aassocnote="D-0-2-0-0"]')
# Out:
# ('quarter_rep.zip', <http.client.HTTPMessage at 0x22c361605c8>)

# %%
target = elem.parent.text.replace('&cr;','').replace('\n','')
hannaum = Hannanum()
token = hannaum.morphs(target)
counter = collections.Counter(token)
len(counter)
# Out:
# 1734

# %%
def del_pattern_dict(pattern, target_dict):
    key_list = []
    for key in target_dict.keys():
        if pattern.match(key):
            key_list.append(key)
    for i in key_list:
        del target_dict[i]

# %%
gae = re.compile('[0-9]+개$')
jaeum = re.compile('[ㄱ-ㅎ]')
sp = re.compile('^[^\w\s]+$')
del_pattern_dict(gae, counter)
del_pattern_dict(jaeum, counter)
del_pattern_dict(sp, counter)

# %%
stop_list = []
with open('stop_word.txt','r',encoding='utf-8') as f:
    stop_list = f.read().split('\n')

# %%
# commons
for stop in stop_list:
    del counter[stop]
# custroms
del counter['II']
del counter['사업']
del counter['개요']
del counter['현황당사']
del counter['사업부문별']
del counter['본사']
del counter['당사']
del counter['산하']
del counter['한국']
del counter['부문']
del counter['내용◆click◆『수주상황』']
del counter['삽입11013#*_수주상황']

# %%
counter.most_common()
# Out:
# [('은', 66),
#  ('고', 37),
#  ('생산', 33),
#  ('CMO', 27),
#  ('대하', 24),
#  ('위하', 19),
#  ('같', 19),
#  ('제품', 18),
#  ('며', 17),
#  ('생산설비', 17),
#  ('바이오의약품', 16),
#  ('의약품', 16),
#  ('통하', 16),
#  ('으며', 15),
#  ('따르', 15),
#  ('관하', 15),
#  ('수', 15),
#  ('중', 14),
#  ('개발', 13),
#  ('기준', 13),
#  ('관련', 13),
#  ('단위', 13),
#  ('연구개발', 12),
#  ('현황', 12),
#  ('시장', 12),
#  ('게', 12),
#  ('고객사', 12),
#  ('주요', 12),
#  ('온실가스', 11),
#  ('글로벌', 10),
#  ('2', 10),
#  ('없', 10),
#  ('서비스', 10),
#  ('CDO', 9),
#  ('현재', 9),
#  ('확대', 9),
#  ('대', 9),
#  ('받', 9),
#  ('원재료', 9),
#  ('관리', 9),
#  ('체결', 9),
#  ('법률', 9),
#  ('세포주', 8),
#  ('고객', 8),
#  ('과정', 8),
#  ('계약', 8),
#  ('해당', 8),
#  ('위험', 8),
#  ('천원', 8),
#  ('공정', 7),
#  ('1', 7),
#  ('주', 7),
#  ('시장규모', 7),
#  ('보유', 7),
#  ('5', 7),
#  ('또는', 7),
#  ('사항', 7),
#  ('적', 7),
#  ('조건', 7),
#  ('환위험', 7),
#  ('규제', 7),
#  ('바', 6),
#  ('진행', 6),
#  ('전체', 6),
#  ('품질관리', 6),
#  ('역량', 6),
#  ('매출', 6),
#  ('이러하', 6),
#  ('4', 6),
#  ('기존', 6),
#  ('2018년', 6),
#  ('가동', 6),
#  ('거나', 6),
#  ('of', 6),
#  ('고객사의', 6),
#  ('않', 6),
#  ('and', 6),
#  ('연구', 6),
#  ('배출', 6),
#  ('CRO', 5),
#  ('바이오시밀러', 5),
#  ('수주', 5),
#  ('산업', 5),
#  ('성장', 5),
#  ('전망', 5),
#  ('어서', 5),
#  ('다', 5),
#  ('필요', 5),
#  ('제약사', 5),
#  ('이전', 5),
#  ('공급', 5),
#  ('2020년', 5),
#  ('삼성바이오로직스', 5),
#  ('예정', 5),
#  ('고객사로부터', 5),
#  ('지정', 5),
#  ('회사', 5),
#  ('말', 5),
#  ('절차', 5),
#  ('지속적', 5),
#  ('내용', 5),
#  ('제공', 5),
#  ('10', 5),
#  ('가격변동', 5),
#  ('계약조건', 5),
#  ('다.', 5),
#  ('배출량', 5),
#  ('개요당사', 4),
#  ('기업', 4),
#  ('영위', 4),
#  ('Bio', 4),
#  ('Service', 4),
#  ('미국', 4),
#  ('자체', 4),
#  ('제약사들', 4),
#  ('제조', 4),
#  ('뜨', 4),
#  ('전', 4),
#  ('소요', 4),
#  ('와의', 4),
#  ('지속', 4),
#  ('강화', 4),
#  ('수립', 4),
#  ('2019년', 4),
#  ('만', 4),
#  ('규모', 4),
#  ('3공장', 4),
#  ('36.', 4),
#  ('정부', 4),
#  ('Capacity', 4),
#  ('한편', 4),
#  ('Tech', 4),
#  ('생산제품', 4),
#  ('적용', 4),
#  ('모든', 4),
#  ('발생', 4),
#  ('담당', 4),
#  ('Development', 4),
#  ('결정', 4),
#  ('매년', 4),
#  ('01', 4),
#  ('리스크', 4),
#  ('노력', 4),
#  ('제외', 4),
#  ('당분기말', 4),
#  ('전기말', 4),
#  ('유동성', 4),
#  ('경우', 4),
#  ('영향', 4),
#  ('개선', 4),
#  ('04', 4),
#  ('a', 4),
#  ('등록', 4),
#  ('신', 4),
#  ('에너지', 4),
#  ('사용량', 4),
#  ('지원', 3),
#  ('이르', 3),
#  ('Contract', 3),
#  ('R&D', 3),
#  ('높', 3),
#  ('제약시장', 3),
#  ('추세', 3),
#  ('기반', 3),
#  ('안정적', 3),
#  ('분야', 3),
#  ('항체의약품', 3),
#  ('플랜트', 3),
#  ('동물세포', 3),
#  ('세포', 3),
#  ('정제', 3),
#  ('GMP', 3),
#  ('각국', 3),
#  ('블록버스터', 3),
#  ('치료제', 3),
#  ('예측', 3),
#  ('활용', 3),
#  ('운영', 3),
#  ('향후', 3),
#  ('1분기말', 3),
#  ('2만리터', 3),
#  ('1위', 3),
#  ('2천리터', 3),
#  ('추', 3),
#  ('총', 3),
#  ('고객사가', 3),
#  ('영업', 3),
#  ('Transfer', 3),
#  ('Process', 3),
#  ('아래', 3),
#  ('표', 3),
#  ('20년', 3),
#  ('환율', 3),
#  ('정기적', 3),
#  ('정보', 3),
#  ('유', 3),
#  ('조정', 3),
#  ('매입', 3),
#  ('백만원', 3),
#  ('작성', 3),
#  ('구매', 3),
#  ('다양한', 3),
#  ('비', 3),
#  ('라', 3),
#  ('내', 3),
#  ('Capa', 3),
#  ('후', 3),
#  ('대상', 3),
#  ('계획', 3),
#  ('수주총액', 3),
#  ('수주잔고', 3),
#  ('4월', 3),
#  ('Inc', 3),
#  ('위험관리', 3),
#  ('도록', 3),
#  ('의무', 3),
#  ('이사회', 3),
#  ('포함', 3),
#  ('당분기', 3),
#  ('거래', 3),
#  ('미치', 3),
#  ('목적', 3),
#  ('MSAT', 3),
#  ('팀', 3),
#  ('생산관련', 3),
#  ('기술지원', 3),
#  ('핵심', 3),
#  ('Yeast', 3),
#  ('연구개발비용', 3),
#  ('밖', 3),
#  ('동법', 3),
#  ('공개', 3),
#  ('화학물질', 3),
#  ('환경', 3),
#  ('저탄소', 3),
#  ('녹색성장', 3),
#  ('오염물질', 3),
#  ('유틸리티', 3),
#  ('시설', 3),
#  ('체제', 2),
#  ('위탁생산', 2),
#  ('임상', 2),
#  ('규제기관', 2),
#  ('더하', 2),
#  ('Manufacturing', 2),
#  ('마케팅', 2),
#  ('사업역량', 2),
#  ('연평균', 2),
#  ('9.8', 2),
#  ('용', 2),
#  ('필수적', 2),
#  ('경쟁력', 2),
#  ('건설', 2),
#  ('배양', 2),
#  ('요구', 2),
#  ('생산기술', 2),
#  ('시험생산', 2),
#  ('의약품규제기관', 2),
#  ('2년', 2),
#  ('이루', 2),
#  ('출시', 2),
#  ('항암제', 2),
#  ('최근', 2),
#  ('에는', 2),
#  ('새롭', 2),
#  ('유망', 2),
#  ('생산분야', 2),
#  ('최소화하기', 2),
#  ('3', 2),
#  ('안정성', 2),
#  ('확보', 2),
#  ('복수', 2),
#  ('수요', 2),
#  ('Site', 2),
#  ('별도', 2),
#  ('크', 2),
#  ('차', 2),
#  ('전세계', 2),
#  ('10월', 2),
#  ('제조시장', 2),
#  ('jpg', 2),
#  ('대형', 2),
#  ('스위스', 2),
#  ('26만리터', 2),
#  ('독일', 2),
#  ('30만리터', 2),
#  ('18', 2),
#  ('세계', 2),
#  ('임상물질', 2),
#  ('특화', 2),
#  ('제조공정', 2),
#  ('기술', 2),
#  ('공급처', 2),
#  ('별', 2),
#  ('6', 2),
#  ('제조허가', 2),
#  ('시스템', 2),
#  ('검증', 2),
#  ('승인', 2),
#  ('2분기', 2),
#  ('면', 2),
#  ('가장', 2),
#  ('프로세스', 2),
#  ('완료', 2),
#  ('생산공정', 2),
#  ('엄격히', 2),
#  ('준수', 2),
#  ('생산공장', 2),
#  ('송도인천', 2),
#  ('판매활동', 2),
#  ('미팅', 2),
#  ('전략적', 2),
#  ('관계', 2),
#  ('판매', 2),
#  ('해외', 2),
#  ('컨퍼런스', 2),
#  ('최신', 2),
#  ('파악', 2),
#  ('설비', 2),
#  ('23', 2),
#  ('확장', 2),
#  ('공정개발', 2),
#  ('중소', 2),
#  ('위탁개발', 2),
#  ('증', 2),
#  ('증가', 2),
#  ('열', 2),
#  ('품질분석', 2),
#  ('Lab', 2),
#  ('현황(단위', 2),
#  ('백만원)사업부문매출유형품목2020년', 2),
#  ('1분기(제10기)2019년도(제9기)2018년도(제8기)금액비중금액비중금액비중CMO제품', 2),
#  ('등항체의약품200,34196.', 2),
#  ('7%648,37592.', 2),
#  ('4%528,22898.', 2),
#  ('6%서비스기타6,8563.', 2),
#  ('3%53,2177.', 2),
#  ('6%7,5781.', 2),
#  ('4%합', 2),
#  ('계207,197100.', 2),
#  ('고객사와', 2),
#  ('반영한', 2),
#  ('비율', 2),
#  ('상승', 2),
#  ('3.', 2),
#  ('Global', 2),
#  ('원', 2),
#  ('전액', 2),
#  ('한국채택국제회계기준', 2),
#  ('연결', 2),
#  ('투입', 2),
#  ('인하', 2),
#  ('제하', 2),
#  ('생산능력', 2),
#  ('60일', 2),
#  ('30일', 2),
#  ('감안', 2),
#  ('분2020년', 2),
#  ('인천광역시', 2),
#  ('임대료', 2),
#  ('충족', 2),
#  ('어렵', 2),
#  ('03', 2),
#  ('매출실', 2),
#  ('수주계약', 2),
#  ('중요', 2),
#  ('부분', 2),
#  ('계약체결', 2),
#  ('기간', 2),
#  ('수주업무', 2),
#  ('불', 2),
#  ('방문', 2),
#  ('검토ㆍ각', 2),
#  ('분야별', 2),
#  ('유관부', 2),
#  ('서', 2),
#  ('검토ㆍ재무', 2),
#  ('Reserve', 2),
#  ('평가', 2),
#  ('물량', 2),
#  ('범위', 2),
#  ('품질', 2),
#  ('인도', 2),
#  ('판매방법', 2),
#  ('바탕', 2),
#  ('참석', 2),
#  ('이후', 2),
#  ('잠재', 2),
#  ('신규', 2),
#  ('상기', 2),
#  ('철저', 2),
#  ('시', 2),
#  ('기술이전', 2),
#  ('Biotechnology', 2),
#  ('계약(약', 2),
#  ('소재', 2),
#  ('위험관리정책', 2),
#  ('적절한', 2),
#  ('한계치', 2),
#  ('상황', 2),
#  ('활동', 2),
#  ('검토', 2),
#  ('이해', 2),
#  ('목표', 2),
#  ('정책', 2),
#  ('적절', 2),
#  ('금융상품', 2),
#  ('계약상', 2),
#  ('의미', 2),
#  ('신용위험', 2),
#  ('노출정도', 2),
#  ('금융부채', 2),
#  ('유지', 2),
#  ('금액', 2),
#  ('유의적', 2),
#  ('①', 2),
#  ('분장부금액계약상현금흐름1년', 2),
#  ('이내1년', 2),
#  ('초과2년', 2),
#  ('이내2년', 2),
#  ('초과3년', 2),
#  ('이내3년', 2),
#  ('전기', 2),
#  ('원화', 2),
#  ('통화', 2),
#  ('시되', 2),
#  ('노출', 2),
#  ('외화차입금', 2),
#  ('환율변동', 2),
#  ('변동시', 2),
#  ('법인세비용차감전순이익', 2),
#  ('상승10%', 2),
#  ('변동', 2),
#  ('이자율', 2),
#  ('상승0.', 2),
#  ('자본구조', 2),
#  ('부채비율', 2),
#  ('계약해당사항', 2),
#  ('콜옵션', 2),
#  ('Therapeutics', 2),
#  ('지분', 2),
#  ('행사', 2),
#  ('었으며', 2),
#  ('인천시', 2),
#  ('건물', 2),
#  ('삼성바이오에피스㈜', 2),
#  ('조직', 2),
#  ('DS1', 2),
#  ('Team', 2),
#  ('DS3', 2),
#  ('공정연구', 2),
#  ('생산성', 2),
#  ('인력', 2),
#  ('작성기준', 2),
#  ('연구인력', 2),
#  ('05', 2),
#  ('18.', 2),
#  ('BMS社', 2),
#  ('05.', 2),
#  ('Merck社', 2),
#  ('Engineering', 2),
#  ('Fermentation', 2),
#  ('with', 2),
#  ('Pilot', 2),
#  ('Derived', 2),
#  ('Recombinant', 2),
#  ('Peptide', 2),
#  ('1992', 2),
#  ('Biotech社', 2),
#  ('개발총괄', 2),
#  ('11', 2),
#  ('비용', 2),
#  ('제조업', 2),
#  ('위반', 2),
#  ('화학물질관리법', 2),
#  ('평', 2),
#  ('사업장', 2),
#  ('환경관리', 2),
#  ('12월', 2),
#  ('최우수', 2),
#  ('권', 2),
#  ('할당', 2),
#  ('녹색경영', 2),
#  ('내용1', 1),
#  ('일괄생산', 1),
#  ('갖추', 1),
#  ('전문적', 1),
#  ('제형ㆍ분석법', 1),
#  ('초', 1),
#  ('개발서비스를제공하', 1),
#  ('Safety', 1),
#  ('Testing', 1),
#  ('으로부터의', 1),
#  ('제조승인취득', 1),
#  ('One', 1),
#  ('Stop', 1),
#  ('Provider', 1),
#  ('지향', 1),
#  ('자회사', 1),
#  ('삼성바이오에피스와아키젠바이오텍', 1),
#  ('상업화', 1),
#  ('사업의안정적', 1),
#  ('해외거점', 1),
#  ('확대운영', 1),
#  ('종속기업', 1),
#  ('Samsung', 1),
#  ('logics', 1),
#  ('America', 1),
#  ('Inc.', 1),
#  ('설립', 1),
#  ('업계', 1),
#  ('특성', 1),
#  ('특성바이오', 1),
#  ('Organization', 1),
#  ('생산역량이부족하거나,', 1),
#  ('집중', 1),
#  ('전략적으로아웃소싱하', 1),
#  ('위탁개발ㆍ생산', 1),
#  ('성장률', 1),
#  ('보이', 1),
#  ('견인', 1),
#  ('빠르', 1),
#  ('활', 1),
#  ('제조원', 1),
#  ('적시', 1),
#  ('생산·공급', 1),
#  ('스피드', 1),
#  ('수주역량이필수적입니', 1),
#  ('주력', 1),
#  ('상업용', 1),
#  ('대규모', 1),
#  ('투자가', 1),
#  ('설계ㆍ건설ㆍ밸리데이션', 1),
#  ('사업화', 1),
#  ('준비', 1),
#  ('최소', 1),
#  ('3년', 1),
#  ('소요되는업', 1),
#  ('특징', 1),
#  ('이용', 1),
#  ('충전', 1),
#  ('Good', 1),
#  ('Practice', 1),
#  ('부합', 1),
#  ('높은수준', 1),
#  ('통해상업용', 1),
#  ('준비기간', 1),
#  ('CMO계약', 1),
#  ('통상', 1),
#  ('5∼10년', 1),
#  ('장기계약', 1),
#  ('성장성', 1),
#  ('성장요인바이오의약품', 1),
#  ('성장요인', 1),
#  ('2000년', 1),
#  ('바이오의약품(자가면역질환', 1),
#  ('당뇨', 1),
#  ('면역', 1),
#  ('고지혈증', 1),
#  ('알츠하이머', 1),
#  ('아토피', 1),
#  ('신약', 1),
#  ('지속적으로출시되', 1),
#  ('아웃소싱', 1),
#  ('시판허가', 1),
#  ('판매수요', 1),
#  ('불확실성', 1),
#  ('위해대규모', 1),
#  ('자본투자', 1),
#  ('전문', 1),
#  ('변화', 1),
#  ('기회', 1),
#  ('작용', 1),
#  ('생산설비(Dual', 1),
#  ('Sourcing', 1),
#  ('권고', 1),
#  ('FDA', 1),
#  ('단', 1),
#  ('에서만', 1),
#  ('Contingency', 1),
#  ('Plan', 1),
#  ('규제강화', 1),
#  ('흐르', 1),
#  ('따라CMO', 1),
#  ('사례', 1),
#  ('특허만료', 1),
#  ('Humira', 1),
#  ('Herceptin', 1),
#  ('Remicade', 1),
#  ('Lantus', 1),
#  ('특허가만료되', 1),
#  ('폭', 1),
#  ('수요증가', 1),
#  ('더욱가속화', 1),
#  ('전망세계', 1),
#  ('2,872억불', 1),
#  ('30.', 1),
#  ('1%비중', 1),
#  ('2024년', 1),
#  ('성장해', 1),
#  ('4,167억불', 1),
#  ('비중', 1),
#  ('33.', 1),
#  ('EvaluatePharma', 1),
#  ('3월', 1),
#  ('119억불', 1),
#  ('10년', 1),
#  ('간', 1),
#  ('연평균13.', 1),
#  ('2025년', 1),
#  ('253억불', 1),
#  ('형성', 1),
#  ('Frost', 1),
#  ('Sullivan', 1),
#  ('cmo', 1),
#  ('전망(3)', 1),
#  ('경기변동', 1),
#  ('특성해당사항', 1),
#  ('경쟁상황당사', 1),
#  ('주류', 1),
#  ('전문으로하', 1),
#  ('생산설비를보유한', 1),
#  ('소수', 1),
#  ('주도하', 1),
#  ('둔Lonza', 1),
#  ('배양설비', 1),
#  ('독일Boehringer', 1),
#  ('Ingelheim', 1),
#  ('리터', 1),
#  ('cGMP', 1),
#  ('시작하여2020년', 1),
#  ('선발업체를추월해', 1),
#  ('도약', 1),
#  ('2분기말부터', 1),
#  ('4만리터', 1),
#  ('자원', 1),
#  ('조달', 1),
#  ('상', 1),
#  ('특성CMO', 1),
#  ('계약제품', 1),
#  ('받아고객사', 1),
#  ('Needs', 1),
#  ('맞', 1),
#  ('원부재료', 1),
#  ('고객사로부터무상사급', 1),
#  ('방식', 1),
#  ('장기계약으로공급받기', 1),
#  ('때문', 1),
#  ('가능', 1),
#  ('법령', 1),
#  ('규제각국', 1),
#  ('품목별', 1),
#  ('신규생산설비', 1),
#  ('현장실사', 1),
#  ('전반', 1),
#  ('거치', 1),
#  ('현황(1)', 1),
#  ('생산당사', 1),
#  ('인천경제자유구역(송도지구)', 1),
#  ('상업제품', 1),
#  ('36만리터(1공장', 1),
#  ('3만,2공장', 1),
#  ('15', 1),
#  ('임상용', 1),
#  ('바이오CMO', 1),
#  ('부상', 1),
#  ('추가적', 1),
#  ('가동개시', 1),
#  ('생산활동', 1),
#  ('우선적', 1),
#  ('공정확립', 1),
#  ('단계별', 1),
#  ('안정성검증', 1),
#  ('생산준비', 1),
#  ('최종적', 1),
#  ('인증용', 1),
#  ('규제기관(FDA,', 1),
#  ('EMA', 1),
#  ('제조승인', 1),
#  ('신청', 1),
#  ('배양공정(Upstream', 1),
#  ('품질스펙', 1),
#  ('따라고품질', 1),
#  ('정제공정(Downstream', 1),
#  ('유효약물', 1),
#  ('거칠', 1),
#  ('생산과정', 1),
#  ('어야', 1),
#  ('검사', 1),
#  ('조치', 1),
#  ('요구할권리', 1),
#  ('결과', 1),
#  ('대해문서화해', 1),
#  ('개요2020년', 1),
#  ('개요]구분1공장2공장3공장위', 1),
#  ('치인천', 1),
#  ('송도규', 1),
#  ('모30,000L(5,000L×6기)154,000L', 1),
#  ('(15,000L×10기,', 1),
#  ('1,000L×4기)※', 1),
#  ('1,000L', 1),
#  ('4기', 1),
#  ('2기', 1),
#  ('2분기말', 1),
#  ('가동예정180,000L', 1),
#  ('(15,000L', 1),
#  ('×12기)공사기간25개월29개월35개월공사비용3,500억원(3억불)', 1),
#  ('7,000억원(6.', 1),
#  ('5억불', 1),
#  ('8,500억원', 1),
#  ('7.', 1),
#  ('4억불', 1),
#  ('현', 1),
#  ('황상업생산상업생산상업생산※', 1),
#  ('미화', 1),
#  ('환산', 1),
#  ('공사비', 1),
#  ('공장', 1),
#  ('건설기간', 1),
#  ('평균', 1),
#  ('산정함(다)', 1),
#  ('에서는', 1),
#  ('영업조직', 1),
#  ('샌프란시스코,', 1),
#  ('보스턴,', 1),
#  ('뉴저지', 1),
#  ('동서부', 1),
#  ('주요거점', 1),
#  ('현지인력', 1),
#  ('수주영업', 1),
#  ('제약회사', 1),
#  ('미팅에서당사', 1),
#  ('CMO서비스', 1),
#  ('제약회사에제공하', 1),
#  ('고자', 1),
#  ('전략', 1),
#  ('일환', 1),
#  ('담당임원', 1),
#  ('참가하여시장', 1),
#  ('기술동향', 1),
#  ('잠재고객', 1),
#  ('접하', 1),
#  ('시장점유율당사', 1),
#  ('18만리터', 1),
#  ('시작', 1),
#  ('Capacity가36.', 1),
#  ('4만리터(단,', 1),
#  ('나머지2천리터', 1),
#  ('사업자에등극하였습니', 1),
#  ('132만리터', 1),
#  ('28%에해당하며,', 1),
#  ('경쟁사', 1),
#  ('Lonza', 1),
#  ('20', 1),
#  ('BoehringerIngelheim', 1),
#  ('신규사업', 1),
#  ('전망당사', 1),
#  ('중심', 1),
#  ('Organi', 1),
#  ('zation', 1),
#  ('로도', 1),
#  ('사업영역', 1),
#  ('No', 1),
#  ('회사로도약하고', 1),
#  ('대상으로세포주ㆍ공정', 1),
#  ('제형개발', 1),
#  ('Small', 1),
#  ('Biotech', 1),
#  ('항체', 1),
#  ('Pipeline', 1),
#  ('성장률이예상되', 1),
#  ('17년', 1),
#  ('11억불', 1),
#  ('22년', 1),
#  ('22억불', 1),
#  ('25년', 1),
#  ('30억불', 1),
#  ('CAGR', 1),
#  ('13.', 1),
#  ('위탁분석(CRO,', 1),
#  ('Research', 1),
#  ('Organiz', 1),
#  ('ation', 1),
#  ('본격적', 1),
#  ('착수', 1),
#  ('◆click◆『수주상황』', 1),
#  ('dsl2', 1),
#  ('0%701,592100%535,806100%나', 1),
#  ('추이당사', 1),
#  ('판매가격', 1),
#  ('최초판매가격', 1),
#  ('공시', 1),
#  ('CPI', 1),
#  ('소비자물가지수', 1),
#  ('정하', 1),
#  ('고정비율', 1),
#  ('만큼', 1),
#  ('사업부문매입유형품', 1),
#  ('목매입액비율비', 1),
#  ('(매입처)CMO원재료Resin', 1),
#  ('등29,69149.', 1),
#  ('Life', 1),
#  ('Sciences', 1),
#  ('Solutions', 1),
#  ('Singapore', 1),
#  ('씨그마알드리치코리아', 1),
#  ('등부재료Filter', 1),
#  ('등30,31750.', 1),
#  ('머크주식회사', 1),
#  ('싸토리우스코리아바이오텍', 1),
#  ('등합', 1),
#  ('계60,008100.', 1),
#  ('0%-※', 1),
#  ('일반적', 1),
#  ('BOM', 1),
#  ('Bill', 1),
#  ('Material', 1),
#  ('속하', 1),
#  ('Handling', 1),
#  ('Fee', 1),
#  ('환급', 1),
#  ('구조', 1),
#  ('취하', 1),
#  ('있음※', 1),
#  ('원인당사', 1),
#  ('사유', 1),
#  ('확인', 1),
#  ('거래처', 1),
#  ('구매한원재료', 1),
#  ('부대비용', 1),
#  ('대부분', 1),
#  ('사전', 1),
#  ('사후', 1),
#  ('정산(환급)이이루어집니', 1),
#  ('관련한위험', 1),
#  ('장기공급계약', 1),
#  ('가격인상', 1),
#  ('관련하', 1),
#  ('물가상승률(약', 1),
#  ('수준', 1),
#  ('인상률을적용하', 1),
#  ('관련한', 1),
#  ('생산실적', 1),
#  ('가동률당사', 1),
#  ('1회', 1),
#  ('실시', 1),
#  ('정기점검(Slowdown)기간', 1),
#  ('330일', 1),
#  ('실제', 1),
#  ('생산여건', 1),
#  ('특성(시생산,인증용', 1),
#  ('상업생산', 1),
#  ('배치생산간격', 1),
#  ('요인', 1),
#  ('반영하여생산능력', 1),
#  ('산출', 1),
#  ('배치', 1),
#  ('1분기(제10기)2019년도(제9기)2018년도(제8기)생산능력142418220생산실적73174155가동률51.', 1),
#  ('4%41.', 1),
#  ('6%70.', 1),
#  ('5%※', 1),
#  ('완공', 1),
#  ('반영함', 1),
#  ('사항(1)', 1),
#  ('현황(단위:', 1),
#  ('백만원)자산별기초취득처분상각기타증감기말비고토지-----', 1),
#  ('-주1)건물718,993---4,89586714,184-구축물9,187---63-9,124-기계장치918,90094--24,70012,450906,744-차량운반구263---39-224-기타18,735334-64-1,72585418,134-건설중인자산36,71510,437---14,03433,118-합',
#   1),
#  ('계1,702,79310,865-64-31,422-6441,681,528-주1)당사', 1),
#  ('임대차계약', 1),
#  ('공유재산관리조례', 1),
#  ('의하', 1),
#  ('감면', 1),
#  ('요건', 1),
#  ('면제', 1),
#  ('음', 1),
#  ('주2)주요', 1),
#  ('유형자산', 1),
#  ('객관적', 1),
#  ('시가판단', 1),
#  ('기재', 1),
#  ('생략', 1),
#  ('투자현황(단위:', 1),
#  ('분투자기간대상자산2020년', 1),
#  ('1분기', 1),
#  ('투자액', 1),
#  ('시ㄴ', 1),
#  ('증설', 1),
#  ('보완', 1),
#  ('등2020.', 1),
#  ('2020.', 1),
#  ('등9,734-5', 1),
#  ('매출실적', 1),
#  ('유형별', 1),
#  ('0%701,592100%535,806100%-', 1),
#  ('지역별', 1),
#  ('1분기(제10기)2019년도(제9기)2018년도(제8기)금액비중금액비중금액비중국내100,10948%207,12029%227,95043%유럽93,72545%418,23460%290,01054%미주13,0917%62,3859%16,1043%기타2720%13,8532%1,7420%합',
#   1),
#  ('계207,197100%701,592100%535,806100%나', 1),
#  ('판매경로당사', 1),
#  ('수주산업', 1),
#  ('것이당사', 1),
#  ('약', 1),
#  ('6~12개월(고객사', 1),
#  ('제안요청', 1),
#  ('접수', 1),
#  ('날', 1),
#  ('진행절차', 1),
#  ('용잠재', 1),
#  ('발굴고객사', 1),
#  ('접촉ㆍ고객사', 1),
#  ('조사(조직,', 1),
#  ('임상진행', 1),
#  ('등)ㆍ전시회', 1),
#  ('참가', 1),
#  ('접촉', 1),
#  ('바이오로직스', 1),
#  ('소개', 1),
#  ('등고객사', 1),
#  ('CMO제안요청(RFP', 1),
#  ('발송', 1),
#  ('담당자', 1),
#  ('미팅ㆍ이메일,', 1),
#  ('전화', 1),
#  ('등ㆍ미팅', 1),
#  ('회의록', 1),
#  ('작성수주', 1),
#  ('가능한물량', 1),
#  ('확인ㆍ비밀유지계약', 1),
#  ('소개자료(Capa', 1),
#  ('송', 1),
#  ('유치', 1),
#  ('등제안서', 1),
#  ('제출리스크', 1),
#  ('차등', 1),
#  ('배치가격', 1),
#  ('검토ㆍ법률', 1),
#  ('수주제품', 1),
#  ('삼성', 1),
#  ('비경쟁', 1),
#  ('검토-ㆍ고객사', 1),
#  ('제안ㆍ계약기간,', 1),
#  ('가능시점', 1),
#  ('가격', 1),
#  ('제공범위', 1),
#  ('최소보장물량', 1),
#  ('고려CMO', 1),
#  ('선정후보', 1),
#  ('선정ㆍ고객사', 1),
#  ('후보', 1),
#  ('선정우선협상대상CMO', 1),
#  ('선정ㆍ최종', 1),
#  ('우선협상대상', 1),
#  ('선정계약조건', 1),
#  ('협의리스크', 1),
#  ('최저보장', 1),
#  ('항목', 1),
#  ('ㆍ법률', 1),
#  ('Liability', 1),
#  ('경쟁조항', 1),
#  ('등기본', 1),
#  ('협의ㆍ주요', 1),
#  ('협상', 1),
#  ('조정ㆍ양해각서(MOU)', 1),
#  ('의향서(LOI)', 1),
#  ('작성세부', 1),
#  ('협의ㆍ본', 1),
#  ('계약(Master', 1),
#  ('Agreement', 1),
#  ('협의수주', 1),
#  ('계약최종계약서', 1),
#  ('교환ㆍ수주', 1),
#  ('계약서', 1),
#  ('작성이후', 1),
#  ('승인(QR,', 1),
#  ('Quality', 1),
#  ('Release', 1),
#  ('시점에매출', 1),
#  ('인식하', 1),
#  ('창고', 1),
#  ('보관', 1),
#  ('재고를고객사', 1),
#  ('장소(일반적', 1),
#  ('캐리', 1),
#  ('대리점', 1),
#  ('판매경로', 1),
#  ('조건당사', 1),
#  ('통해개별적', 1),
#  ('연간', 1),
#  ('최소생산물량', 1),
#  ('구매요청(PO)한', 1),
#  ('장소', 1),
#  ('식', 1),
#  ('대금청구', 1),
#  ('종료', 1),
#  ('시점에이루어지며,', 1),
#  ('대금', 1),
#  ('청구', 1),
#  ('이내', 1),
#  ('회수', 1),
#  ('판매전략당사', 1),
#  ('홈페이지', 1),
#  ...]

# %% [markdown]
# # 기준
# ## 언급 횟수가 많을수록 키워드
# ## 다른 종목에서 언급이 안됐을수록 키워드
# ## 특수문자가 포함되면 키워드가 아님
