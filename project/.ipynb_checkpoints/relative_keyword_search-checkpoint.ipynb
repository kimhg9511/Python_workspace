# %% [markdown]
# # module import

# %%
import requests
from bs4 import BeautifulSoup as bs
# import pandas as pd
import fileIO as io

# %% [markdown]
# # 데이터 불러오기

# %%
keywords_csv = io.csv_to_list("rtop20_stocks.csv")
keywords_list_addrel = list(map(lambda i:i.split(","), keywords_csv))
keywords_list = list(map(lambda i:i.split(",")[0], keywords_csv))
# keywords_list

# %% [markdown]
# # 테스트

# %%
url = 'https://search.naver.com/search.naver'
keyword = '조비'
params = {
    "sm" : "top_hty",
    "fbm" : "1",
    "ie" : "utf8",
    "query" : keyword
}
resp = requests.get(url, params=params)
soup = bs(resp.text, 'html.parser')
rel_keywords = soup.select_one('.relate_area')
if rel_keywords == None:
    print('연관검색어가 없음')
# print(list(map(lambda i:i.text.strip(), rel_keywords)))
# print(rel_keywords)
# Out:
# 연관검색어가 없음

# %% [markdown]
# # 실행

# %%
for keyword, item in zip(keywords_list, keywords_list_addrel):
    url = 'https://search.naver.com/search.naver'
#     keyword = '셀트리온헬스케어'
    params = {
        "sm" : "top_hty",
        "fbm" : "1",
        "ie" : "utf8",
        "query" : keyword
    }
    resp = requests.get(url, params=params)
    soup = bs(resp.text, 'html.parser')
    rel_keywords_area = soup.select_one('.relate_area')
    rel_keywords = []
    if rel_keywords_area == None:
        pass
    else:
        rel_keywords = list(map(lambda i:i.text.strip(), rel_keywords_area.select('li')))
    item.append(rel_keywords)

# %%
keywords_list_addrel
# Out:
# [['영화테크',
#   '2020-07-06 12:31:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['우정바이오',
#   '2020-07-06 08:43:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['덕양산업',
#   '2020-07-06 10:22:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['파멥신',
#   '2020-07-06 17:22:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['엠게임',
#   '2020-07-06 10:24:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['마인',
#   '2020-07-06 03:50:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['조비',
#   '2020-07-06 09:19:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['녹십자셀',
#   '2020-07-06 14:17:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['넷마블',
#   '2020-07-06 10:53:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['신도기연',
#   '2020-07-06 07:50:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']],
#  ['부국철강',
#   '2020-07-06 13:24:00',
#   ['폐배터리 관련주', '나노신소재', '파워로직스', '테이팩스', '코스모화학', '두산퓨얼셀', '2차전지 관련주'],
#   ['비츠로테크', '제일바이오', '모비스', '세스코 주가', '세스코 관련주', '음압병실 관련주'],
#   ['조비',
#    '덕양',
#    '인지컨트롤스',
#    '코넥',
#    '덕양산업사망사고',
#    '상아프론테크',
#    '새한산업',
#    '덕양산업 사망',
#    '덕양산업사고',
#    '서연이화'],
#   ['파멥신 무상증자',
#    '파멥신 주가',
#    '펩트론',
#    '에이비엘바이오',
#    '파맵신 무상증자',
#    '무상증자',
#    '파멥신 권리락',
#    '제넥신',
#    '레고켐바이오',
#    '셀리드'],
#   ['넷마블',
#    '한게임',
#    '웹젠',
#    '라피스',
#    '게임 관련주',
#    'mgame baduk',
#    '엠게임바둑',
#    '컴투스',
#    '넥슨',
#    '넥슨지티'],
#   ['마인 원피스',
#    '영화 마인',
#    'mine',
#    '마인 영화',
#    '타임',
#    '마인 아울렛',
#    '구호',
#    '마인 뜻',
#    '마인 블라우스',
#    '마인 코트'],
#   [],
#   ['녹십자랩셀',
#    '녹십자',
#    '녹십자엠에스',
#    'gc녹십자셀',
#    '녹십자웰빙',
#    '녹십자홀딩스',
#    'gc녹십자',
#    '녹십자셀주가',
#    '녹십자셀 코로나',
#    '삼성전자'],
#   ['엔씨소프트',
#    '넥슨',
#    '넷마블 빅히트',
#    '넷마블 주가',
#    '디피씨',
#    '넥슨지티',
#    '빅히트 엔터테인먼트',
#    '카카오',
#    '한게임',
#    '빅히트 상장'],
#   ['위더스제약',
#    '신도기연 청약',
#    '신도기연 상장',
#    '소마젠',
#    '신도기연 상장일',
#    '신도기연 공모',
#    '신도기연주가',
#    '에이프로',
#    '공모주',
#    '티에스아이'],
#   ['부국철강 이낙연',
#    '범양건영',
#    '남선알미늄',
#    '부국',
#    '서원',
#    'sdn',
#    '이월드',
#    '이낙연 관련주',
#    '남화토건',
#    '남화산업']]]
