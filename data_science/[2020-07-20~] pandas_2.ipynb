# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('DataScience/data/02. sales-funnel.xlsx')

# %%
df.head()
# Out:
#    Account                          Name            Rep       Manager  \
# 0   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 1   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 2   714466               Trantow-Barrows   Craig Booker  Debra Henley
# 3   737550  Fritsch, Russel and Anderson   Craig Booker  Debra Henley
# 4   146832                  Kiehn-Spinka  Daniel Hilton  Debra Henley
#
#        Product  Quantity  Price     Status
# 0          CPU         1  30000  presented
# 1     Software         1  10000  presented
# 2  Maintenance         2   5000    pending
# 3          CPU         1  35000   declined
# 4          CPU         2  65000        won

# %% [markdown]
# # pivot table

# %%
# pd.pivot_table(df, index=["Name"])
# pd.pivot_table(df, index=["Name","Rep","Manager"])
# pd.pivot_table(df, index=["Manager", "Rep"], values=["Price"])
# pd.pivot_table(df, index=["Manager", "Rep"], 
#                values=["Price"],
#                aggfunc=[np.sum, len])
# pd.pivot_table(df, index=["Manager", "Rep"], 
#                 values=["Price"],
#                 columns=["Product"],
#                 aggfunc=[np.sum, len],
#                 fill_value=0)
pd.pivot_table(df, index=["Manager", "Rep", "Product"], 
                values=["Price", "Quantity"],
                aggfunc=[np.sum, np.mean],
                fill_value=0,
                margins=True)
# Out:
#                                             sum                   mean  \
#                                           Price Quantity         Price
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU           65000        2  32500.000000
#                             Maintenance    5000        2   5000.000000
#                             Software      10000        1  10000.000000
#               Daniel Hilton CPU          105000        4  52500.000000
#                             Software      10000        1  10000.000000
#               John Smith    CPU           35000        1  35000.000000
#                             Maintenance    5000        2   5000.000000
# Fred Anderson Cedric Moss   CPU           95000        3  47500.000000
#                             Maintenance    5000        1   5000.000000
#                             Software      10000        1  10000.000000
#               Wendy Yule    CPU          165000        7  82500.000000
#                             Maintenance    7000        3   7000.000000
#                             Monitor        5000        2   5000.000000
# All                                      522000       30  30705.882353
#
#
#                                          Quantity
# Manager       Rep           Product
# Debra Henley  Craig Booker  CPU          1.000000
#                             Maintenance  2.000000
#                             Software     1.000000
#               Daniel Hilton CPU          2.000000
#                             Software     1.000000
#               John Smith    CPU          1.000000
#                             Maintenance  2.000000
# Fred Anderson Cedric Moss   CPU          1.500000
#                             Maintenance  1.000000
#                             Software     1.000000
#               Wendy Yule    CPU          3.500000
#                             Maintenance  3.000000
#                             Monitor      2.000000
# All                                      1.764706

# %% [markdown]
# # seaborn

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
x = np.linspace(0, 14, 100)
y1 = np.sin(x)
y2 = 2*np.sin(x+0.5)
y3 = 3*np.sin(x+1.0)
y4 = 4*np.sin(x+1.5)

plt.figure(figsize=(10, 6))
plt.plot(x,y1, x,y2, x,y3, x,y4)
plt.show()

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
plt.plot(x,y1, x,y2, x,y3, x,y4)
sns.despine(offset=10)
plt.show()

# %% [markdown]
# # 요일별 점심, 저녁, 흡연 여부 식사 금액과 팁

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

sns.set_style('whitegrid')
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.figure(figsize=(2,6))
sns.boxplot(y=tips['total_bill'])
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="day", y="total_bill", data=tips)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="day",
            y="total_bill",
            hue="smoker",
            data=tips,
            palette="Set3")
plt.show()

# %%
plt.figure(figsize=(8,6))
# swarmplot은 stripplot과 비슷하지만 데이터를 나타내는 점이 겹치지 않도록 옆으로 이동
sns.swarmplot(x="day", y="total_bill", data=tips, color=".5")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x="day", y="total_bill", data=tips)
sns.swarmplot(x="day", y="total_bill", data=tips, color=".25")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.lmplot(x="total_bill", y="tip", hue="smoker", data=tips, height=7)
plt.show()

# %%
uniform_data = np.random.rand(10, 12)
uniform_data
# Out:
# array([[0.71974388, 0.78941985, 0.0839835 , 0.2238493 , 0.57126404,
#         0.16293803, 0.96855586, 0.93009371, 0.67935225, 0.59879479,
#         0.46003927, 0.57089211],
#        [0.94329775, 0.19579628, 0.24914881, 0.57281436, 0.85637516,
#         0.76486629, 0.90975795, 0.81587121, 0.66672342, 0.43502574,
#         0.43416338, 0.97069168],
#        [0.0850672 , 0.24183553, 0.79732572, 0.59648993, 0.4356108 ,
#         0.8838801 , 0.3214563 , 0.05471161, 0.60370749, 0.31359492,
#         0.37476334, 0.40513166],
#        [0.24102026, 0.68780705, 0.98434818, 0.50023673, 0.22116026,
#         0.43523072, 0.33050648, 0.8629395 , 0.12226894, 0.38292816,
#         0.46764084, 0.0400109 ],
#        [0.43056924, 0.86536511, 0.91475822, 0.38668426, 0.61124327,
#         0.87511771, 0.87912831, 0.35562166, 0.45235992, 0.84170759,
#         0.8083813 , 0.38518467],
#        [0.2586486 , 0.44700088, 0.30514738, 0.20788025, 0.81859783,
#         0.08386773, 0.62576002, 0.08698598, 0.6501315 , 0.0590631 ,
#         0.40877789, 0.64948315],
#        [0.77086991, 0.04363714, 0.40090616, 0.19834298, 0.11312626,
#         0.86949369, 0.90408958, 0.99978502, 0.80033571, 0.7821256 ,
#         0.81039561, 0.65843896],
#        [0.8739173 , 0.98041586, 0.8165813 , 0.35019644, 0.34024534,
#         0.90940317, 0.93204711, 0.93202079, 0.42807497, 0.50164446,
#         0.73940509, 0.19109549],
#        [0.23935404, 0.43906525, 0.22251013, 0.74358985, 0.2257903 ,
#         0.8154157 , 0.25647443, 0.67838815, 0.11531841, 0.3517835 ,
#         0.55305861, 0.20303107],
#        [0.43786829, 0.23154603, 0.39648755, 0.92483586, 0.49766416,
#         0.82146323, 0.19807253, 0.00841427, 0.03897475, 0.55828572,
#         0.54304514, 0.39617673]])

# %%
sns.heatmap(uniform_data, vmin=0, vmax=1)
plt.show()

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights = flights.pivot('month', 'year', 'passengers')
flights.head()
# Out:
# year      1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January    112   115   145   171   196   204   242   284   315   340   360
# February   118   126   150   180   196   188   233   277   301   318   342
# March      132   141   178   193   236   235   267   317   356   362   406
# April      129   135   163   181   235   227   269   313   348   348   396
# May        121   125   172   183   229   234   270   318   355   363   420
#
# year      1960
# month
# January    417
# February   391
# March      419
# April      461
# May        472

# %%
plt.figure(figsize=(10,8))
sns.heatmap(flights, annot=True, fmt="d")
plt.show()

# %%
sns.set(style="ticks")
iris = sns.load_dataset('iris')
iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
plt.figure(figsize=(10,8))
sns.pairplot(iris, hue="species")
plt.show()

# %%
sns.pairplot(iris, vars=["sepal_width", "sepal_length"])
plt.show()

# %%
sns.pairplot(iris, x_vars=["sepal_width", "sepal_length"], 
             y_vars=["petal_width", "petal_length"])
plt.show()
